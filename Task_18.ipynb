# %% [markdown]
# <a href="https://colab.research.google.com/github/LiuChen-5749342/Generative-AI-and-AI-Applications/blob/main/Task_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 18**
# (check the python notebook SD4 - Synthetic Loan Data Generation with CTGAN & TVAE.ipynb for context and further details)
#
# Load the file fraud_transactions.csv and create a synthetic data set of 5000 records. Evaluate the quality of the synthetic data created.

# %% [markdown]
# In fact, task 18 is the same as task 13. To find more information on this task, there's a link to workout of task 13, which has the same results.

# %% [markdown]
# https://colab.research.google.com/drive/1iWOBO3xYdEUz9IWjQMpudFYRXt-LaZB6
